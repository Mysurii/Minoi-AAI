# %%
import numpy as np

from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from tensorflow.keras.optimizers import Adam

from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape + (1,))
    
x_test = x_test.astype('float32') / 255.
x_test = x_test.reshape(x_test.shape + (1,))

# %%
input_dim = (28, 28, 1)
z_dim = 2

# %% [markdown]
# ### Encoder

# %%
encoder_input = Input(input_dim, name = 'encoder_input')

x = Conv2D(filters = 32,
           kernel_size = 3,
           padding = 'same',
           name = 'encoder_conv_1')(encoder_input)
x = LeakyReLU()(x)

x = Conv2D(filters = 64,
           kernel_size = 3,
           strides = (2,2),
           padding = 'same',
           name = 'encoder_conv_2')(x)
x = LeakyReLU()(x)

x = Conv2D(filters = 64,
           kernel_size = 3,
           strides = (2,2),
           padding = 'same',
           name = 'encoder_conv_3')(x)
x = LeakyReLU()(x)

x = Conv2D(filters = 32,
           kernel_size = 3,
           padding = 'same',
           name = 'encoder_conv_4')(x)
x = LeakyReLU()(x)

shape_before_flattening = K.int_shape(x)[1:]

x = Flatten()(x)

# %% [markdown]
# De encoder komt overeen met de `encoder` van de autoencoder. Het verschil zit in de volgende stap, waarin twee parallele Dense lagen het gemiddelde en de log van de variantie teruggeven.

# %%
mu = Dense(z_dim, name = 'mu')(x)
log_var = Dense(z_dim, name = 'log_var')(x)

# %%
def sampling(args):
    mu, log_var = args
    epsilon = K.random_normal(shape = K.shape(mu), mean = 0, stddev =  1.)
    return mu + K.exp(log_var / 2) * epsilon

# %% [markdown]
# Een `Lambda` laag is een manier om een willekeurige bewerking in een Keras laag uit te voeren.
# Onderstaande laag kiest een willekeurig getal volgens de verdeling bepaald door `mu` en `log_var`.

# %%
encoder_output = Lambda(sampling, name = 'encoder_output')([mu, log_var])

encoder = Model(encoder_input, encoder_output)

# %%
encoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 28, 28, 1)]  0           []
#
#  encoder_conv_1 (Conv2D)        (None, 28, 28, 32)   320         ['encoder_input[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 28, 28, 32)   0           ['encoder_conv_1[0][0]']
#
#  encoder_conv_2 (Conv2D)        (None, 14, 14, 64)   18496       ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 14, 14, 64)   0           ['encoder_conv_2[0][0]']
#
#  encoder_conv_3 (Conv2D)        (None, 7, 7, 64)     36928       ['leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 7, 7, 64)     0           ['encoder_conv_3[0][0]']
#
#  encoder_conv_4 (Conv2D)        (None, 7, 7, 32)     18464       ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 7, 7, 32)     0           ['encoder_conv_4[0][0]']
#
#  flatten (Flatten)              (None, 1568)         0           ['leaky_re_lu_3[0][0]']
#
#  mu (Dense)                     (None, 2)            3138        ['flatten[0][0]']
#
#  log_var (Dense)                (None, 2)            3138        ['flatten[0][0]']
#
#  encoder_output (Lambda)        (None, 2)            0           ['mu[0][0]',
#                                                                   'log_var[0][0]']
#
# ==================================================================================================
# Total params: 80,484
# Trainable params: 80,484
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Bekijk de `summary` van de encoder. Komt deze overeen met je verwachtingen?

# %% [markdown]
# ### Decoder
#
# De `decoder` komt overeen met de `decoder` van de Autoencoder.

# %%
decoder_input = Input((z_dim,), name = 'decoder_input')

x = Dense(np.prod(shape_before_flattening))(decoder_input)
x = Reshape(shape_before_flattening)(x) # van een dense vector naar de vorm van een afbeelding

x = Conv2DTranspose(filters = 64,
                kernel_size = 3,
                padding = 'same',
                name = 'decoder_conv_t_1')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 64,
                kernel_size = 3,
                strides = (2,2),
                padding = 'same',
                name = 'decoder_conv_t_2')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 32,
                kernel_size = 3,
                strides = (2,2),
                padding = 'same',
                name = 'decoder_conv_t_3')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 1,
                kernel_size = 3,
                padding = 'same',
                name = 'decoder_conv_t_4')(x)
x = LeakyReLU()(x)

decoder_output = Activation('sigmoid')(x)

decoder = Model(decoder_input, decoder_output)

# %%
decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense (Dense)               (None, 1568)              4704
#
#  reshape (Reshape)           (None, 7, 7, 32)          0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 7, 7, 64)         18496
#  nspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 14, 14, 64)        0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 32)        0
#
#  decoder_conv_t_4 (Conv2DTra  (None, 28, 28, 1)        289
#  nspose)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 1)         0
#
#  activation (Activation)     (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 78,881
# Trainable params: 78,881
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### De volledige variational autoencoder

# %%
vae = Model(encoder_input, decoder(encoder_output))

# %%
r_loss_factor = 1500

def r_loss(y_true, y_pred):
    return r_loss_factor * K.mean(K.square(y_true - y_pred), axis = [1,2,3])

def vae_kl_loss(y_true, y_pred):
    return -0.5 * K.sum(1 + log_var - K.square(mu) - K.exp(log_var), axis = 1)

def vae_loss(y_true, y_pred):
    return r_loss(y_true, y_pred) + vae_kl_loss(y_true, y_pred)

# %% [markdown]
# Compileer en train de variational autoencoder.

# %%
learning_rate = 0.0005

optimizer = Adam(lr = learning_rate)

vae.compile(optimizer = optimizer, loss = vae_loss,  metrics = [r_loss, vae_kl_loss])
# Out:
# /Users/aliozcan/miniforge3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
subset = 20000

vae.fit(x = x_train[:subset], y = x_train[:subset], batch_size = 32, epochs = 7, shuffle = True)
# Out:
# Train on 20000 samples
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-05-19 21:50:44.290998: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-19 21:50:44.291478: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-05-19 21:50:44.315984: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-19 21:50:44.316655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 21:50:44.362368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/7
# 2022-05-19 21:50:44.492134: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 21:50:44.508914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 21:50:44.516553: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 20000/20000 [==============================] - 12s 578us/sample - loss: 102.9225 - r_loss: 99.0525 - vae_kl_loss: 3.8700
# Epoch 2/7
# 20000/20000 [==============================] - 11s 556us/sample - loss: 83.6961 - r_loss: 80.0245 - vae_kl_loss: 3.6716
# Epoch 3/7
# 20000/20000 [==============================] - 11s 545us/sample - loss: 80.7928 - r_loss: 76.8803 - vae_kl_loss: 3.9125
# Epoch 4/7
# 20000/20000 [==============================] - 11s 547us/sample - loss: 78.6796 - r_loss: 74.5300 - vae_kl_loss: 4.1496
# Epoch 5/7
# 20000/20000 [==============================] - 11s 553us/sample - loss: 77.1605 - r_loss: 72.8262 - vae_kl_loss: 4.3343
# Epoch 6/7
# 20000/20000 [==============================] - 11s 553us/sample - loss: 75.8406 - r_loss: 71.3696 - vae_kl_loss: 4.4710
# Epoch 7/7
# 20000/20000 [==============================] - 11s 553us/sample - loss: 75.0599 - r_loss: 70.4461 - vae_kl_loss: 4.6138

# %% [markdown]
# ### Reconstructie van originele afbeeldingen
#
# We selecteren willekeurige afbeeldingen, coderen deze met de `encoder` en decoderen deze met de `decoder`.

# %%
import matplotlib.pyplot as plt

n = 10

# selecteer willekeurige afbeeldingen uit x_test
idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[idx]

# vertaal met de encoder naar getallen
z_points = encoder.predict(test_images)

# vertaal de getallen met de decoder terug naar afbeeldingen
reconstr_images = decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n):
    img = test_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')
    
for i in range(n):
    img = reconstr_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + n + 1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')
# Out:
# /Users/aliozcan/miniforge3/lib/python3.8/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2022-05-19 21:52:04.738026: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 21:52:04.824727: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# **Opdracht:**
#
# Wat valt je op aan de reconstructies?

# %% [markdown]
# Ze zijn waziger geworden

# %% [markdown]
# Om een beter beeld te krijgen van het gedrag van de autoencoder, plotten we de outputs van de encoder (de 'z-waarden') voor een deel van de testset. De kleur van een punt geeft het correcte label weer.
#
# Daarnaast selecteren we alvast een aantal willekeurige punten (dus een combinatie van twee willekeurige getallen) die we dadelijk gaan gebruiken om volledig nieuwe afbeeldingen te genereren. Deze punten worden in het rood weergegeven.

# %%
n = 5000
grid_size = 10
grid_depth = 3
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[example_idx]
test_labels = y_test[example_idx]

z_points = encoder.predict(test_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap = 'rainbow' , c = test_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

# %% [markdown]
# **Opdracht:**
#
# Wat valt je op aan deze plot, vergeleken met dezelfde plot bij de Autoencoder?

# %% [markdown]
# Deze plot is meer dicht op elkaar geplakt. De variatie is heel wat kleiner.

# %% [markdown]
# We gebruiken nu de decoder om op basis van de willekeurig gegenereerde punten volledig nieuwe afbeeldingen te genereren en plotten deze afbeeldingen.

# %%
reconst = decoder.predict(z_grid)

figsize = 15
fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %% [markdown]
# Ze zijn nog steds wazig.

# %% [markdown]
# Bonus: Varieer nu eens met het aantal lagen en filters in de encoder en decoder of met `z_dim` het aantal waarden in de vector `z`. Kun je de decoder een volledig andere vorm geven dan de encoder? Hoe beïnvloedt dit het resultaat?
